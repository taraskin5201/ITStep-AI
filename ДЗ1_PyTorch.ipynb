# %% [markdown]
# <a href="https://www.kaggle.com/code/taraskin5201/1-pytorch?scriptVersionId=294064199" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Ваша задача методом градієнтного спуску побудувати модель для прогнозу ціни на діаманти

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/diamonds.csv",
                 index_col=0)

df.head()
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335

# %% [markdown]
# Формула моделі
# $$
#           pred = coef*carat + intercept
# $$
# * coef - ціна за один карат
# * intercept - витрати
#
#
# <br>
# <br>
# Формула для ображунку похибки
#
# $$
#           loss = mean((pred - price)^2)
# $$
#
# * pred - ціна, спрогнозована моделю
# * price - справжня ціна

# %%
# імпорт модуля
import torch


carat = df['carat'].to_numpy()
price = df['price'].to_numpy()

# вага в каратах
carat = torch.tensor(carat, dtype=torch.float32)

# справжня ціна
price = torch.tensor(price, dtype=torch.float32)

# %%
# створіть тензори з градієнтом, оберіть довільне початкове значення, тип даних float32
coef = torch.tensor(1.0, dtype=torch.float32, requires_grad=True)
intercept = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

# вкажіть навчальний крок
lr = 0.01

# визначення оптимізатора
optimizer = torch.optim.SGD([coef, intercept], lr=lr)

# основний цикл
for t in range(2000):
  # обрахуйте прогноз моделі за формулою наведеною вище
    pred = coef * carat + intercept

  # обрахуйте похибку між справжньою ціною та прогнозованою
    loss = torch.mean((pred - price) ** 2)

  # виведіть значення похибки для кожного сотого кроку
    if t % 100 == 0:
        print(f"Step {t}: loss = {loss.item()}")

  # обрахуйте градієнти по метриці
    loss.backward()

    optimizer.step()
    
    optimizer.zero_grad()
# Out:
# Step 0: loss = 31372490.0
# Step 100: loss = 6463262.5
# Step 200: loss = 4804207.5
# Step 300: loss = 3828970.0
# Step 400: loss = 3248994.5
# Step 500: loss = 2904078.0
# Step 600: loss = 2698951.75
# Step 700: loss = 2576961.0
# Step 800: loss = 2504412.0
# Step 900: loss = 2461266.0
# Step 1000: loss = 2435607.0
# Step 1100: loss = 2420347.0
# Step 1200: loss = 2411272.0
# Step 1300: loss = 2405874.75
# Step 1400: loss = 2402665.0
# Step 1500: loss = 2400756.0
# Step 1600: loss = 2399620.75
# Step 1700: loss = 2398945.75
# Step 1800: loss = 2398544.25
# Step 1900: loss = 2398305.25

# %% [markdown]
# # Результат

# %%
coef.item(), intercept.item()
# Out:
# (7726.888671875, -2229.2783203125)

# %% [markdown]
# # Порівняйте результат з sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
X_train = df.drop(columns=['price'])
y_train = df['price']
# тренування
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0], model.intercept_
# Out:
# (np.float64(7756.425617968435), np.float64(-2256.360580045403))
