# %% [markdown]
# <a href="https://www.kaggle.com/code/taraskin5201/notebook64fb3dee4d?scriptVersionId=291900524" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Імпорт модулів

# %% [markdown]
# # Завдання 1
#
# Перегляньте інформацію про доступні процесори, та виведіть про них інформацію

# %% [markdown]
# # Завдання 2
# Підключіть colab до процесора GPU, та знову виведіть інформацію про доступні процесори

# %% [markdown]
# # Завдання 3
# Створіть випадковий тензор розміру (2, 3). Виведіть інформацію про його:
#
# * розмір
# * тип даних
# * процесор
# * наявність градієнта

# %% [markdown]
# # Завдання 4
#
# Створіть 2 тензора розміру 100. Виведіть
# * суму векторів
# * частку векторів(перед цим замініть один елемент на 0)
# * максимальне та мінімальне значення(методи .min() .max())
# * середнє значення(метод .mean())
# * квадрад різниці
# * середнє значення квадрату різниці

# %% [markdown]
# # Завдання 7
# Застосуйте метод градієнтного для розв'язання рівняння f(x)=y_true

# %%
def f(x):
  return x**2/3 + torch.sin(torch.pi*x)

y_true = 3

# %%
import torch
from torch.optim import SGD

x = torch.tensor(-3.5, requires_grad=True)

optimizer = SGD([x],
                lr=0.01)

for epoch in range(100):

    nn_result = f(x)

    error = (y_true - nn_result)**2

    error.backward()

    optimizer.step()

    optimizer.zero_grad()
    
    print(epoch, error)
# Out:
# 0 tensor(4.3403, grad_fn=<PowBackward0>)
# 1 tensor(3.2882, grad_fn=<PowBackward0>)
# 2 tensor(1.9118, grad_fn=<PowBackward0>)
# 3 tensor(0.7507, grad_fn=<PowBackward0>)
# 4 tensor(0.2050, grad_fn=<PowBackward0>)
# 5 tensor(0.0473, grad_fn=<PowBackward0>)
# 6 tensor(0.0105, grad_fn=<PowBackward0>)
# 7 tensor(0.0023, grad_fn=<PowBackward0>)
# 8 tensor(0.0005, grad_fn=<PowBackward0>)
# 9 tensor(0.0001, grad_fn=<PowBackward0>)
# 10 tensor(2.5152e-05, grad_fn=<PowBackward0>)
# 11 tensor(5.5847e-06, grad_fn=<PowBackward0>)
# 12 tensor(1.2423e-06, grad_fn=<PowBackward0>)
# 13 tensor(2.7512e-07, grad_fn=<PowBackward0>)
# 14 tensor(6.1482e-08, grad_fn=<PowBackward0>)
# 15 tensor(1.3704e-08, grad_fn=<PowBackward0>)
# 16 tensor(3.1392e-09, grad_fn=<PowBackward0>)
# 17 tensor(7.0037e-10, grad_fn=<PowBackward0>)
# 18 tensor(1.5370e-10, grad_fn=<PowBackward0>)
# 19 tensor(4.1439e-11, grad_fn=<PowBackward0>)
# 20 tensor(8.1855e-12, grad_fn=<PowBackward0>)
# 21 tensor(2.7853e-12, grad_fn=<PowBackward0>)
# 22 tensor(0., grad_fn=<PowBackward0>)
# 23 tensor(0., grad_fn=<PowBackward0>)
# 24 tensor(0., grad_fn=<PowBackward0>)
# 25 tensor(0., grad_fn=<PowBackward0>)
# 26 tensor(0., grad_fn=<PowBackward0>)
# 27 tensor(0., grad_fn=<PowBackward0>)
# 28 tensor(0., grad_fn=<PowBackward0>)
# 29 tensor(0., grad_fn=<PowBackward0>)
# 30 tensor(0., grad_fn=<PowBackward0>)
# 31 tensor(0., grad_fn=<PowBackward0>)
# 32 tensor(0., grad_fn=<PowBackward0>)
# 33 tensor(0., grad_fn=<PowBackward0>)
# 34 tensor(0., grad_fn=<PowBackward0>)
# 35 tensor(0., grad_fn=<PowBackward0>)
# 36 tensor(0., grad_fn=<PowBackward0>)
# 37 tensor(0., grad_fn=<PowBackward0>)
# 38 tensor(0., grad_fn=<PowBackward0>)
# 39 tensor(0., grad_fn=<PowBackward0>)
# 40 tensor(0., grad_fn=<PowBackward0>)
# 41 tensor(0., grad_fn=<PowBackward0>)
# 42 tensor(0., grad_fn=<PowBackward0>)
# 43 tensor(0., grad_fn=<PowBackward0>)
# 44 tensor(0., grad_fn=<PowBackward0>)
# 45 tensor(0., grad_fn=<PowBackward0>)
# 46 tensor(0., grad_fn=<PowBackward0>)
# 47 tensor(0., grad_fn=<PowBackward0>)
# 48 tensor(0., grad_fn=<PowBackward0>)
# 49 tensor(0., grad_fn=<PowBackward0>)
# 50 tensor(0., grad_fn=<PowBackward0>)
# 51 tensor(0., grad_fn=<PowBackward0>)
# 52 tensor(0., grad_fn=<PowBackward0>)
# 53 tensor(0., grad_fn=<PowBackward0>)
# 54 tensor(0., grad_fn=<PowBackward0>)
# 55 tensor(0., grad_fn=<PowBackward0>)
# 56 tensor(0., grad_fn=<PowBackward0>)
# 57 tensor(0., grad_fn=<PowBackward0>)
# 58 tensor(0., grad_fn=<PowBackward0>)
# 59 tensor(0., grad_fn=<PowBackward0>)
# 60 tensor(0., grad_fn=<PowBackward0>)
# 61 tensor(0., grad_fn=<PowBackward0>)
# 62 tensor(0., grad_fn=<PowBackward0>)
# 63 tensor(0., grad_fn=<PowBackward0>)
# 64 tensor(0., grad_fn=<PowBackward0>)
# 65 tensor(0., grad_fn=<PowBackward0>)
# 66 tensor(0., grad_fn=<PowBackward0>)
# 67 tensor(0., grad_fn=<PowBackward0>)
# 68 tensor(0., grad_fn=<PowBackward0>)
# 69 tensor(0., grad_fn=<PowBackward0>)
# 70 tensor(0., grad_fn=<PowBackward0>)
# 71 tensor(0., grad_fn=<PowBackward0>)
# 72 tensor(0., grad_fn=<PowBackward0>)
# 73 tensor(0., grad_fn=<PowBackward0>)
# 74 tensor(0., grad_fn=<PowBackward0>)
# 75 tensor(0., grad_fn=<PowBackward0>)
# 76 tensor(0., grad_fn=<PowBackward0>)
# 77 tensor(0., grad_fn=<PowBackward0>)
# 78 tensor(0., grad_fn=<PowBackward0>)
# 79 tensor(0., grad_fn=<PowBackward0>)
# 80 tensor(0., grad_fn=<PowBackward0>)
# 81 tensor(0., grad_fn=<PowBackward0>)
# 82 tensor(0., grad_fn=<PowBackward0>)
# 83 tensor(0., grad_fn=<PowBackward0>)
# 84 tensor(0., grad_fn=<PowBackward0>)
# 85 tensor(0., grad_fn=<PowBackward0>)
# 86 tensor(0., grad_fn=<PowBackward0>)
# 87 tensor(0., grad_fn=<PowBackward0>)
# 88 tensor(0., grad_fn=<PowBackward0>)
# 89 tensor(0., grad_fn=<PowBackward0>)
# 90 tensor(0., grad_fn=<PowBackward0>)
# 91 tensor(0., grad_fn=<PowBackward0>)
# 92 tensor(0., grad_fn=<PowBackward0>)
# 93 tensor(0., grad_fn=<PowBackward0>)
# 94 tensor(0., grad_fn=<PowBackward0>)
# 95 tensor(0., grad_fn=<PowBackward0>)
# 96 tensor(0., grad_fn=<PowBackward0>)
# 97 tensor(0., grad_fn=<PowBackward0>)
# 98 tensor(0., grad_fn=<PowBackward0>)
# 99 tensor(0., grad_fn=<PowBackward0>)

# %%
import matplotlib.pyplot as plt

xs = torch.linspace(-3, 5, 100)
plt.plot(xs.cpu(), f(xs).cpu(), label='f(x)')
plt.scatter(x.item(), f(x).item(), c='red', label='min')
plt.legend()

# %%
f(x)
# Out:
# tensor(3., grad_fn=<AddBackward0>)

# %% [markdown]
# # Завдання 8
# Застосуйте метод градієнтного спуску для розв'язання рівняня f(x, y)=result_true

# %%
def f1(x, y):
  # функція Швефеля
  return  418.9829*2 - x*torch.sin(x.abs().sqrt()) - y*torch.sin(y.abs().sqrt())

def f2(x, y):
  # трьохгорбна функція
  return 2*x**2  - 1.05*x**4 + 1/6*x**6 + x*y  + y**2

def f3(x, y):
  # функція птах
  return 106.7645 + torch.sin(x)*torch.exp((1-torch.cos(y))**2) + \
  torch.cos(y)*torch.exp((1-torch.sin(x))**2) + \
  (x-y)**2

result_true = 0
